# %% [markdown]
# # Explore here

# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/logistic-regression-project-tutorial/main/bank-marketing-campaign-data.csv", sep = ";")
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
# Valores Nulos

data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
# Valores Duplicados

dup=data.duplicated().sum()
print(dup)
# Out:
# 12

# %%
registros_dup=data[data.duplicated(keep=False)]
registros_dup
# Out:
#        age          job   marital            education  default housing loan  \
# 1265    39  blue-collar   married             basic.6y       no      no   no
# 1266    39  blue-collar   married             basic.6y       no      no   no
# 12260   36      retired   married              unknown       no      no   no
# 12261   36      retired   married              unknown       no      no   no
# 14155   27   technician    single  professional.course       no      no   no
# 14234   27   technician    single  professional.course       no      no   no
# 16819   47   technician  divorced          high.school       no     yes   no
# 16956   47   technician  divorced          high.school       no     yes   no
# 18464   32   technician    single  professional.course       no     yes   no
# 18465   32   technician    single  professional.course       no     yes   no
# 20072   55     services   married          high.school  unknown      no   no
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
print(data.shape)
# Out:
# (41176, 21)

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
data['marital'].value_counts()
# Out:
# marital
# married     24921
# single      11564
# divorced     4611
# unknown        80
# Name: count, dtype: int64

# %%
data['education'].value_counts()
# Out:
# education
# university.degree      12164
# high.school             9512
# basic.9y                6045
# professional.course     5240
# basic.4y                4176
# basic.6y                2291
# unknown                 1730
# illiterate                18
# Name: count, dtype: int64

# %%
data['default'].value_counts()
# Out:
# default
# no         32577
# unknown     8596
# yes            3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
# Analisis de Variables categoricas 

fig, axis = plt.subplots(3, 4, figsize = (20, 15))

# Crear un histograma múltiple
sns.histplot(ax = axis[0, 0], data = data, x = "job")
sns.histplot(ax = axis[0, 1], data = data, x = "job", stat="percent")
sns.histplot(ax = axis[0, 2], data = data, x = "education")
sns.histplot(ax = axis[0, 3], data = data, x = "education", stat="percent")
sns.histplot(ax = axis[1, 0], data = data, x = "housing")
sns.histplot(ax = axis[1, 1], data = data, x = "housing", stat="percent")
sns.histplot(ax = axis[1, 2], data = data, x = "loan")
sns.histplot(ax = axis[1, 3], data = data, x = "loan", stat="percent")
sns.histplot(ax = axis[2, 0], data = data, x = "marital")
sns.histplot(ax = axis[2, 1], data = data, x = "marital", stat="percent")
sns.histplot(ax = axis[2, 2], data = data, x = "default")
sns.histplot(ax = axis[2, 3], data = data, x = "default", stat="percent")

# Rotar las etiquetas
for ax in axis.flat:
    ax.tick_params(axis='x', rotation=45)

# Ajustar el layout
plt.tight_layout()



# Mostrar el plot
plt.show()

# %%
# Analisis de Variables categoricas relacionadas a las campañas de mkt

fig, axis = plt.subplots(4, 2, figsize = (20, 15))

# Crear un histograma múltiple
sns.histplot(ax = axis[0, 0], data = data, x = "month")
sns.histplot(ax = axis[0, 1], data = data, x = "month", stat="percent")
sns.histplot(ax = axis[1, 0], data = data, x = "poutcome")
sns.histplot(ax = axis[1, 1], data = data, x = "poutcome", stat="percent")
sns.histplot(ax = axis[2, 0], data = data, x = "campaign")
sns.histplot(ax = axis[2, 1], data = data, x = "campaign", stat="percent")
sns.histplot(ax = axis[3, 0], data = data, x = "pdays")
sns.histplot(ax = axis[3, 1], data = data, x = "pdays", stat="percent")
# sns.histplot(ax = axis[4, 0], data = data, x = "poutcome")
# sns.histplot(ax = axis[4, 1], data = data, x = "poutcome", stat="percent")



# Ajustar el layout
plt.tight_layout()


# Mostrar el plot
plt.show()

# %%
# Analisis de variables numericas

fig, axis = plt.subplots(4, 2, figsize = (10, 14), gridspec_kw = {"height_ratios": [6, 1, 6, 1]})

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 1], data = data, x = "age")
sns.boxplot(ax = axis[1, 0], data = data, x = "age")
sns.histplot(ax = axis[0, 1], data = data, x = "duration")
sns.boxplot(ax = axis[1, 1], data = data, x = "duration")
sns.histplot(ax = axis[2, 0], data = data, x = "campaign")
sns.boxplot(ax = axis[3, 0], data = data, x = "campaign")


# Ajustar el layout
plt.tight_layout()
fig.delaxes(axis[2, 1])
fig.delaxes(axis[3, 1])

# Mostrar el plot
plt.show()

# %%
# Factorizar
data["job_f"] = pd.factorize(data["job"])[0]
data["marital_f"] = pd.factorize(data["marital"])[0]
data["education_f"] = pd.factorize(data["education"])[0]
data['default_f']=pd.factorize(data["default"])[0]
data['housing_f']=pd.factorize(data["housing"])[0]
data['loan_f']=pd.factorize(data["loan"])[0]
data['month_f']=pd.factorize(data["month"])[0]
data['poutcome_f']=pd.factorize(data["poutcome"])[0]
data['y_f']=pd.factorize(data["y"])[0]

# %%
fig, axis = plt.subplots(figsize = (12, 6))
matriz_corr=data[['job_f',"age",'marital_f','y_f','education_f','default_f','housing_f','loan_f','month_f',"duration",'poutcome_f', "campaign"]].corr()
#print(matriz_corr)
sns.heatmap(matriz_corr, annot = True, fmt = ".2f")

plt.tight_layout()

plt.show()

# %%
# Revision de Datos Atipicos
fig, axis = plt.subplots(4, 3, figsize = (15, 10))

sns.boxplot(ax = axis[0, 0], data = data, y = "y_f")
sns.boxplot(ax = axis[0, 1], data = data, y = "age")
sns.boxplot(ax = axis[0, 2], data = data, y = "job_f")
sns.boxplot(ax = axis[1, 0], data = data, y = "education_f")
sns.boxplot(ax = axis[1, 1], data = data, y = "marital_f")
sns.boxplot(ax = axis[1, 2], data = data, y = "default_f")
sns.boxplot(ax = axis[2, 0], data = data, y = "housing_f")
sns.boxplot(ax = axis[2, 1], data = data, y = "loan_f")
sns.boxplot(ax = axis[2, 2], data = data, y = "month_f")
sns.boxplot(ax = axis[3, 0], data = data, y = "duration")
sns.boxplot(ax = axis[3, 1], data = data, y = "poutcome_f")
sns.boxplot(ax = axis[3, 2], data = data, y = "campaign")

plt.tight_layout()
plt.show()

# %%
data['y'].value_counts()
# Out:
# y
# no     36548
# yes     4640
# Name: count, dtype: int64

# %%
sns.countplot(data=data,x='y',hue='y')
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
# Escalado de valores

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split

# %%
num_variables = ['age','job_f','marital_f', 'education_f', "default_f", "housing_f", "loan_f", "month_f", "duration", "poutcome_f", "duration",'campaign', "emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed", "y_f"]

# Escalamos el modelo

scaler = MinMaxScaler()
scal_features = scaler.fit_transform(data[num_variables])
data_scal =pd.DataFrame(scal_features, index = data.index, columns = num_variables)
data_scal.head()
# Out:
#         age     job_f  marital_f  education_f  default_f  housing_f  loan_f  \
# 0  0.481481  0.000000        0.0     0.000000        0.0        0.0     0.0
# 1  0.493827  0.090909        0.0     0.142857        0.5        0.0     0.0
# 2  0.246914  0.090909        0.0     0.142857        0.0        0.5     0.0
# 3  0.283951  0.181818        0.0     0.285714        0.0        0.0     0.0
# 4  0.481481  0.090909        0.0     0.142857        0.0        0.0     0.5
#
#    month_f  duration  poutcome_f  duration  campaign  emp.var.rate  \
# 0      0.0  0.053070         0.0  0.053070       0.0        0.9375
# 1      0.0  0.030297         0.0  0.030297       0.0        0.9375
# 2      0.0  0.045954         0.0  0.045954       0.0        0.9375
# 3      0.0  0.030704         0.0  0.030704       0.0        0.9375
# 4      0.0  0.062424         0.0  0.062424       0.0        0.9375
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y_f
# ...

# %%
# Feature selection

from sklearn.feature_selection import chi2, SelectKBest
from sklearn.model_selection import train_test_split

X = data_scal.drop("y_f", axis = 1)
y = data_scal["y_f"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)



X_train.head()
# Out:
#             age     job_f  marital_f  education_f  default_f  housing_f  \
# 38651  0.061728  0.363636   0.333333     0.571429        0.0        0.5
# 12733  0.432099  0.181818   0.666667     0.857143        0.5        0.0
# 35807  0.370370  0.090909   0.666667     0.142857        0.0        0.5
# 1423   0.259259  0.272727   0.000000     0.000000        0.0        0.5
# 52     0.530864  0.181818   0.000000     0.142857        0.0        0.0
#
#        loan_f   month_f  duration  poutcome_f  duration  campaign  \
# 38651     0.0  0.555556  0.072794         0.0  0.072794  0.000000
# 12733     0.0  0.222222  0.053274         0.0  0.053274  0.000000
# 35807     0.0  0.000000  0.193778         0.0  0.193778  0.036364
# 1423      0.0  0.000000  0.081944         0.0  0.081944  0.018182
# 52        0.0  0.000000  0.051444         0.0  0.051444  0.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# ...

# %%
# Seleccion de mejores variables para hacer las predicciones con el modelo

selection_model = SelectKBest(chi2, k = 5)
selection_model.fit(X_train, y_train)
ix = selection_model.get_support()
X_train_sel = pd.DataFrame(selection_model.transform(X_train), columns = X_train.columns.values[ix])
X_test_sel = pd.DataFrame(selection_model.transform(X_test), columns = X_test.columns.values[ix])

X_train_sel.head()
# Out:
#     month_f  poutcome_f  emp.var.rate  euribor3m  nr.employed
# 0  0.555556         0.0      0.000000   0.019497     0.203781
# 1  0.222222         0.0      1.000000   0.981183     1.000000
# 2  0.000000         0.0      0.333333   0.138291     0.512287
# 3  0.000000         0.0      0.937500   0.956926     0.859735
# 4  0.000000         0.0      0.937500   0.957379     0.859735

# %%
X_test_sel.head()
# Out:
#     month_f  poutcome_f  emp.var.rate  euribor3m  nr.employed
# 0  0.000000         0.5      0.333333   0.150759     0.512287
# 1  0.000000         0.0      0.937500   0.958059     0.859735
# 2  0.000000         0.5      0.333333   0.153933     0.512287
# 3  0.111111         0.0      1.000000   0.982317     1.000000
# 4  0.222222         0.0      1.000000   0.981410     1.000000

# %%
X_train_sel["y_n"] = list(y_train)
X_test_sel["y_n"] = list(y_test)
X_train_sel.to_csv("../data/processed/clean_train.csv", index = False)
X_test_sel.to_csv("../data/processed/clean_test.csv", index = False)

# %%
# Inicialización y entrenamiento del modelo
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Predicciones y Confiabilidad del Modelo

y_pred = model.predict(X_test)
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9077445982034474

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

trab = confusion_matrix(y_test, y_pred)

# Dibujaremos esta matriz para hacerla más visual
trab_df = pd.DataFrame(trab)

plt.figure(figsize = (3, 3))
sns.heatmap(trab_df, annot=True, fmt="d", cbar=False)

plt.tight_layout()

plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.98      0.95      3657
#          1.0       0.66      0.37      0.48       462
#
#     accuracy                           0.91      4119
#    macro avg       0.79      0.67      0.71      4119
# weighted avg       0.89      0.91      0.90      4119

# %%
# Optimización del modelo

from sklearn.model_selection import GridSearchCV

# Definimos los parámetros que queremos ajustar a mano
hyperparams = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100,500, 1000],
    "penalty": ["l1", "l2", "elasticnet", None],
    "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]
}

# Inicializamos la cuadrícula
grid = GridSearchCV(model, hyperparams, scoring = "accuracy", cv = 7)
grid
# Out:
# GridSearchCV(cv=7, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 500, 1000],
#                          'penalty': ['l1', 'l2', 'elasticnet', None],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']},
#              scoring='accuracy')

# %%
grid.fit(X_train, y_train)

print(f"Mejores hiperparámetros: {grid.best_params_}")
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1208: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1208: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1208: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1208: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1208: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
# Paso 4: Análisis de variables multivariante

# Analisis de variables numericas-numericas


fig, axis = plt.subplots(2, 2, figsize = (10, 16))

sns.regplot(ax = axis[0, 0], data = data, x = "campaign", y = "poutcome")
sns.heatmap(data[["poutcome", "campaign"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)

# sns.regplot(ax = axis[0, 1], data = data, x = "number_of_reviews", y = "price").set(ylabel = None)
# sns.heatmap(data[["price", "number_of_reviews"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])

# fig.delaxes(axis[2, 1])
# fig.delaxes(axis[3, 1])

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 8
#       1 # Paso 4: Análisis de variables multivariante
#       2
#       3 # Analisis de variables numericas-numericas
#       6 fig, axis = plt.subplots(2, 2, figsize = (10, 16))
# ----> 8 sns.regplot(ax = axis[0, 0], data = data, x = "campaign", y = "poutcome")
#       9 sns.heatmap(data[["poutcome", "campaign"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)
#      11 # sns.regplot(ax = axis[0, 1], data = data, x = "number_of_reviews", y = "price").set(ylabel = None)
#      12 # sns.heatmap(data[["price", "number_of_reviews"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])
#      13
#    (...)
#      16
#      17 # Adjust layout
#
# ...
